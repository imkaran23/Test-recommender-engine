# %% [markdown]
# <i>Copyright (c) Microsoft Corporation. All rights reserved.</i>
#
# <i>Licensed under the MIT License.</i>

# %% [markdown]
# # LightFM -  hybrid matrix factorisation (Python, CPU)

# %%
import sys
sys.path.append("../")
import os
import pickle

import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

import lightfm
from lightfm import LightFM
from lightfm.data import Dataset
from lightfm import cross_validation

# Import LightFM's evaluation metrics
from lightfm.evaluation import precision_at_k as lightfm_prec_at_k
from lightfm.evaluation import recall_at_k as lightfm_recall_at_k

# Import repo's evaluation metrics
from reco_utils.evaluation.python_evaluation import (
    precision_at_k, recall_at_k)

from reco_utils.common.timer import Timer
from reco_utils.dataset import movielens
from reco_utils.recommender.lightfm.lightfm_utils import (
    track_model_metrics, prepare_test_df, prepare_all_predictions,
    compare_metric, similar_users, similar_items)

print("System version: {}".format(sys.version))
print("LightFM version: {}".format(lightfm.__version__))
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\lightfm\_lightfm_fast.py:9: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   warnings.warn('LightFM was compiled without OpenMP support. '
# System version: 3.7.3 (default, Apr 24 2019, 15:29:51) [MSC v.1915 64 bit (AMD64)]
# LightFM version: 1.15

# %% [markdown]
# ### Defining variables

# %%
# default number of recommendations
K = 20
# percentage of data used for testing
TEST_PERCENTAGE = 0.2
# model learning rate
LEARNING_RATE = 0.005
# no of latent factors
NO_COMPONENTS = 20
# no of epochs to fit model
NO_EPOCHS = 20
# no of threads to fit model
NO_THREADS = 8
# regularisation for both user and item features
ITEM_ALPHA=1e-6
USER_ALPHA=1e-6

# seed for pseudonumber generations
SEEDNO = 42

# %% [markdown]
# ###  Retrieve data

# %%
def func(x):
    return random.randint(1,5)
def func1(x,y):
    return str(x)+'|'+str(y)
def func2(x,y):
    return str(x)+'|'+str(y)

# %%
# data = pd.read_csv("../../Post dataset/views.csv")
# data = data.merge(pd.read_csv("../../Post dataset/posts.csv"), on='itemID')
# data = data.merge(pd.read_csv("../../Post dataset/users.csv"), on='userID')
# data['rating'] = 0
# data['rating'] = data.apply(lambda x: func(x['rating']),axis=1)
# data['item_features'] = data.apply(lambda x: func1(x['post_type'],x['category']),axis=1)
# data['user_features'] = data.apply(lambda x: func2(x['gender'],x['academics']),axis=1)
# data.drop(columns=['timestamp','name','title','post_type','category','gender','academics'],inplace=True)
# data = data[['userID','itemID','rating','item_features','user_features']]
# data.to_csv('../../Post dataset/data.csv',index=False)

data = pd.read_csv('../Post dataset/data.csv')
data.head()
# Out:
#                      userID                    itemID  rating  \
# 0  5df49b32cc709107827fb3c7  5ec821ddec493f4a2655889e       4
# 1  5df49b32cc709107827fb3c7  5ec1fd0974f7660d73aa0fd5       1
# 2  5df49b32cc709107827fb3c7  5ecd5d417023451e662235c5       4
# 3  5df49b32cc709107827fb3c7  5ecb72c0eaff6b0c3a58a48e       2
# 4  5df49b32cc709107827fb3c7  5ea5aacd10426255a7aa9b71       3
#
#                                        item_features         user_features
# 0  artwork|Visual Arts|Graphic Design|Artistic de...  female|undergraduate
# 1                                   artwork|Drawings  female|undergraduate
# 2          blog|Computer Technology|Machine Learning  female|undergraduate
# 3  artwork|Photography|Architecture|Visual Arts|G...  female|undergraduate
# 4                                        project|nan  female|undergraduate

# %% [markdown]
# ### Prepare data

# %%
dataset = Dataset()

# %%
dataset.fit(users=data['userID'], 
            items=data['itemID'])

# quick check to determine the number of unique users and items in the data
num_users, num_topics = dataset.interactions_shape()
print(f'Num users: {num_users}, num_topics: {num_topics}.')
# Out:
# Num users: 118, num_topics: 493.

# %%
(interactions, weights) = dataset.build_interactions(data.iloc[:, 0:2].values)
print(repr(interactions))
# Out:
# <118x493 sparse matrix of type '<class 'numpy.int32'>'
# 	with 1447 stored elements in COOrdinate format>

# %%
train_interactions, test_interactions = cross_validation.random_train_test_split(
    interactions, test_percentage=TEST_PERCENTAGE,
    random_state=np.random.RandomState(SEEDNO))

# %%
print(f"Shape of train interactions: {train_interactions.shape}")
print(f"Shape of test interactions: {test_interactions.shape}")
# Out:
# Shape of train interactions: (118, 493)
# Shape of test interactions: (118, 493)

# %% [markdown]
# ### Fit the LightFM model

# %%
model1 = LightFM(loss='warp', no_components=NO_COMPONENTS, 
                 learning_rate=LEARNING_RATE,                 
                 random_state=np.random.RandomState(SEEDNO))

# %%
model1.fit(interactions=train_interactions,
          epochs=NO_EPOCHS);

# %% [markdown]
# ### Prepare model evaluation data

# %%
uids, iids, interaction_data = cross_validation._shuffle(
    interactions.row, interactions.col, interactions.data, 
    random_state=np.random.RandomState(SEEDNO))

cutoff = int((1.0 - TEST_PERCENTAGE) * len(uids))
test_idx = slice(cutoff, None)

# %%
uid_map, ufeature_map, iid_map, ifeature_map = dataset.mapping()

# %%
with Timer() as test_time:
    test_df = prepare_test_df(test_idx, uids, iids, uid_map, iid_map, weights)
print(f"Took {test_time.interval:.1f} seconds for prepare and predict test data.")  
time_reco1 = test_time.interval
# Out:
# Took 0.2 seconds for prepare and predict test data.

# %%
test_df.sample(5)
# Out:
#                        userID                    itemID  rating
# 73   5d610ae1653a331687083239  5e9f3f16a3258347b42f2e3c     1.0
# 137  5d60098a653a331687083238  5ea7cd9610426255a7aa9bd2     1.0
# 254  5deeef6142a8854bf6eabab9  5ec7a8bdec493f4a26558846     1.0
# 202  5deeef6142a8854bf6eabab9  5eb6e04ffd92f539c465dd8f     1.0
# 84   5e8cbd92a3258347b42f2699  5d81323a6c53455f896e6044     1.0

# %% [markdown]
# In addition, the predictions of all unseen user-item pairs (e.g. removing those seen in the training data) can be prepared as follows:

# %%
with Timer() as test_time:
    all_predictions = prepare_all_predictions(data, uid_map, iid_map, 
                                              interactions=train_interactions,
                                              model=model1, 
                                              num_threads=NO_THREADS)
print(f"Took {test_time.interval:.1f} seconds for prepare and predict all data.")
time_reco2 = test_time.interval
# Out:
# Took 17.6 seconds for prepare and predict all data.

# %%
all_predictions.sample(5)
# Out:
#                          userID                    itemID  prediction
# 12867  5ed3e898bd514d602c1530de  5e81bf73a3258347b42f2257   -0.079701
# 21107  5ed2399b76027d35905cc70f  5e95a06da3258347b42f29b4   -0.067782
# 8940   5ed2edf176027d35905cc961  5e9f3f16a3258347b42f2e3c   -0.067442
# 28360  5ecf6e6576027d35905cbeec  5e9f40b2a3258347b42f2e45   -0.145933
# 16078  5e35a5ed8d344822fed4d13e  5ec3bc1a74f7660d73aa1207   -0.227776

# %% [markdown]
# ### Model evaluation

# %%
with Timer() as test_time:
    eval_precision = precision_at_k(rating_true=test_df, 
                                rating_pred=all_predictions, k=K)
    eval_recall = recall_at_k(test_df, all_predictions, k=K)
time_reco3 = test_time.interval

# with Timer() as test_time:
#     eval_precision_lfm = lightfm_prec_at_k(model1, test_interactions, 
#                                            train_interactions, k=K).mean()
#     eval_recall_lfm = lightfm_recall_at_k(model1, test_interactions, 
#                                           train_interactions, k=K).mean()
# time_lfm = test_time.interval
    
print(
    "------ Using Repo's evaluation methods ------",
    f"Precision@K:\t{eval_precision:.6f}",
    f"Recall@K:\t{eval_recall:.6f}",
#     "\n------ Using LightFM evaluation methods ------",
#     f"Precision@K:\t{eval_precision_lfm:.6f}",
#     f"Recall@K:\t{eval_recall_lfm:.6f}", 
    sep='\n')
# Out:
# ------ Using Repo's evaluation methods ------
# Precision@K:	0.034328
# Recall@K:	0.133274

# %% [markdown]
# ## Recommender with LightFM using explicit feedbacks and additional item and user features

# %% [markdown]
# ### Extract and prepare item features

# %%
# split based on the separator
item_features = [x.split('|') for x in data['item_features']]
# retrieve the all the unique in the data
all_item_features = sorted(list(set(itertools.chain.from_iterable(item_features))))
# quick look at the all the within the data
all_item_features
# Out:
# ['2D Composition',
#  'Accounting',
#  'Accounting Theory And Practices',
#  'Acrylics',
#  'Advertising',
#  'Alternate Dispute Resolution',
#  'Animal Biotechnology',
#  'Applied Ethics',
#  'Archeology',
#  'Architecture',
#  'Art',
#  'Art; Science',
#  'Articulation',
#  'Artificial Intelligence',
#  'Artistic design',
#  'Atomic Physics',
#  'Audit Evidence',
#  'Audit Remark',
#  'Auditing',
#  'Banking',
#  'Banking Companies',
#  'Banking Law',
#  'Banking Technology',
#  'Basics of Communiaction',
#  'Bio-entrepreneurship',
#  'Biotechnology',
#  'Break even Point',
#  'Business',
#  'Business Enviorment',
#  'Business Management',
#  'Business Organisation',
#  'Business Planning',
#  'Business Skills',
#  'Business Strategies',
#  'Calligraphy',
#  'Cardiology',
#  'Ceramics',
#  'Child Development',
#  'Cloud Computing',
#  'Colonialism In India',
#  'Communication',
#  'Company Law',
#  'Competition Laws',
#  'Computation',
#  'Computer Application',
#  'Computer Creation',
#  'Computer Technology',
#  'Conceptual',
#  'Corporate Accounting',
#  'Corporate Social Responsibilities',
#  'Cost Audit',
#  'Craft',
#  'Craft work',
#  'Creative And Lateral Management',
#  'Custom Laws',
#  'Data Science',
#  'Database Management',
#  'Design and Analysis of Algorithms',
#  'Digital India',
#  'Digital Marketing',
#  'Direct Tax',
#  'Drawing',
#  'Drawings',
#  'E Commerce',
#  'E Transactions',
#  'Eco System',
#  'Ecology',
#  'Economic Policies',
#  'Economics',
#  'Economics Sociology',
#  'Education',
#  'Electrical Machines',
#  'Electronics & electrical Technology',
#  'Empowerment',
#  'Energy Physics',
#  'Entreperneurship',
#  'Environment Studies',
#  'Environmental Biology',
#  'Environmental Biotechnology',
#  'Fashion Communication',
#  'Fashion Desigining',
#  'Fashion Design',
#  'Fashion Illustration',
#  'Fashion Manufacturing',
#  'Fashion Portfoilio',
#  'Fashion Techniques',
#  'Fashion Textile',
#  'Fashion Trends',
#  'Fictions',
#  'Finance',
#  'Financial Accounting',
#  'Financial Analysis',
#  'Fine Arts',
#  'Foreign Business',
#  'Foreign Economy',
#  'Frontend Development',
#  'Fundamental Of Accounting',
#  'Fundamental Rights',
#  'GST',
#  'Garment Production',
#  'Garment Technology',
#  'Gastroenterology',
#  'Genetic Engineering',
#  'Geography',
#  'Government Law',
#  'Government and Politics',
#  'Graphic',
#  'Graphic Design',
#  'Graphics',
#  'HR Management',
#  'Hardware',
#  'Health Education',
#  'History',
#  'Human Prehistory',
#  'Human Resources',
#  'Human Rights',
#  'Humanities',
#  'Illustration',
#  'Income Tax Laws',
#  'Indian Economy',
#  'Indian Geography',
#  'Indian Government',
#  'Indian History',
#  'Industrial Instrumentation',
#  'Information Technology',
#  'Inorganic Chemistry',
#  'Instrumentation',
#  'Internal Audit',
#  'Internal Financial Control',
#  'International Agreement',
#  'International Marketing',
#  'International Politics',
#  'International Relations',
#  'International Treaties',
#  'Labor Law',
#  'Learning',
#  'Legal Studies',
#  'Legal System',
#  'Legal Tradition',
#  'Linear Algebra',
#  'Literature',
#  'Logic',
#  'Logo Design',
#  'Machine Learning',
#  'Management',
#  'Managerial Activity',
#  'Marketing',
#  'Marketing Management',
#  'Marketing Research Methadology',
#  'Mass Media',
#  'Mathematics',
#  'Media And Society',
#  'Mixed Media',
#  'Mobile Applications',
#  'Molecular Biology',
#  'Mosaic painting',
#  'Movements in Literature',
#  'Music',
#  'NGO',
#  'Nationality Law',
#  'Neurology',
#  'New Venture Planning',
#  'Nuclear & Particle Physics',
#  'Operating Systems',
#  'Organizational Behaviour',
#  'Osteology',
#  'Other Online Platforms',
#  'Painting',
#  'Partnership Accounting',
#  'Pattern & Culture',
#  'Pattern Cutting',
#  'Pen and ink',
#  'Performance In Organization',
#  'Philosophy',
#  'Photography',
#  'Physical Geography',
#  'Physics',
#  'Physiology',
#  'Plant Biotechnology',
#  'Political Science',
#  'Political Thought',
#  'Pollution',
#  'Principles Of Marketing',
#  'Prints',
#  'Professionalism',
#  'Programming languages',
#  'Promotion And Distribution Decisions',
#  'Protection & Enforcement',
#  'Psycholgy',
#  'Psychological Growth',
#  'Public Philosophy',
#  'Quantum Mecahnics',
#  'Radiology',
#  'Revenue Concept',
#  'Rights and Duties',
#  'Robotics',
#  'Science; Technology',
#  'Science;Technology',
#  'Sculptures',
#  'Secratarial Audit',
#  'Shopping Platform',
#  'Sketch Video',
#  'Social Interventions',
#  'Social Psychology',
#  'Social Tech',
#  'Social Work',
#  'Sociology',
#  'Sociology in India',
#  'Sociology of Religion',
#  'Sports Coaching',
#  'Sports Event',
#  'Sports Law',
#  'Start Ups',
#  'Statuary Audit',
#  'Stories',
#  'Substance Abuse',
#  'Tapestry',
#  'Taxation',
#  'Team Mangememnt',
#  'Technology',
#  'Technology Mangement',
#  'Test',
#  'Typography',
#  'Venture Capitalist',
#  'ViDEO',
#  'Video',
#  'Video editing',
#  'Videography',
#  'Visual Arts',
#  'Watercolours',
#  'Web designing',
#  'Wood Crafts',
#  'Wood carving',
#  'Zoology',
#  'artwork',
#  'blog',
#  'nan',
#  'project',
#  'skill']

# %% [markdown]
# #### Extract and prepare user features

# %%
# split based on the separator
user_features = [x.split('|') for x in data['user_features']]
# retrieve the all the unique in the data
all_user_features = sorted(list(set(itertools.chain.from_iterable(user_features))))
# quick look at the all the within the data
user_features, all_user_features
# Out:
# ([['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['female', 'graduate'],
#   ['male', 'undergraduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['male', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'graduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['female', 'graduate'],
#   ['male', 'undergraduate'],
#   ['male', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ['female', 'undergraduate'],
#   ...],
#  ['female', 'graduate', 'male', 'undefined', 'undergraduate'])

# %% [markdown]
# ### Prepare data and features

# %%
dataset2 = Dataset()
dataset2.fit(data['userID'], 
            data['itemID'], 
            item_features=all_item_features,
            user_features=all_user_features)

# %%
item_features = dataset2.build_item_features(
    (x, y) for x,y in zip(data.itemID, item_features))
with open('item_features.pickle', 'wb') as file:
    pickle.dump(item_features, file, protocol=pickle.HIGHEST_PROTOCOL)
item_features
# Out:
# <493x732 sparse matrix of type '<class 'numpy.float32'>'
# 	with 1916 stored elements in Compressed Sparse Row format>

# %%
user_features = dataset2.build_user_features(
    (x, y) for x,y in zip(data.userID, user_features))
with open('user_features.pickle', 'wb') as file:
    pickle.dump(user_features, file, protocol=pickle.HIGHEST_PROTOCOL)
user_features
# Out:
# <118x123 sparse matrix of type '<class 'numpy.float32'>'
# 	with 352 stored elements in Compressed Sparse Row format>

# %%
(interactions2, weights2) = dataset2.build_interactions(data.iloc[:, 0:2].values)

train_interactions2, test_interactions2 = cross_validation.random_train_test_split(
    interactions2, test_percentage=TEST_PERCENTAGE,
    random_state=np.random.RandomState(SEEDNO))
with open('train_interactions2.pickle', 'wb') as file:
    pickle.dump(train_interactions2, file, protocol=pickle.HIGHEST_PROTOCOL)
train_interactions2
# Out:
# <118x493 sparse matrix of type '<class 'numpy.int32'>'
# 	with 1157 stored elements in COOrdinate format>

# %% [markdown]
# ### Hyperparams Tuning

# %%
LEARNING_RATEs = np.linspace(0.5, 0.0001 , num=5)
ALPHAs = np.linspace(1e-5, 1e-7 , num=2)
LEARNING_RATEs = [0.375025]
ALPHAs = [1e-07]
uids, iids, interaction_data = cross_validation._shuffle(
                interactions2.row, interactions2.col, interactions2.data, 
                random_state=np.random.RandomState(SEEDNO))
uid_map, ufeature_map, iid_map, ifeature_map = dataset2.mapping()
test_df2 = prepare_test_df(test_idx, uids, iids, uid_map, iid_map, weights2)

best_precision = 0
for lr in LEARNING_RATEs:
    for a in ALPHAs:
        ia = ua = a
        model2 = LightFM(loss='warp', no_components=NO_COMPONENTS, 
                         learning_rate=lr, 
                         item_alpha=ia,
                         user_alpha=ua,
                         random_state=np.random.RandomState(SEEDNO))

        model2.fit(interactions=train_interactions2,
                   user_features=user_features,
                   item_features=item_features,
                   epochs=NO_EPOCHS);

        all_predictions2 = prepare_all_predictions(data, uid_map, iid_map, 
                                                      interactions=train_interactions2,
                                                       user_features=user_features,
                                                       item_features=item_features,
                                                       model=model2,
                                                       num_threads=NO_THREADS)
        eval_precision2 = precision_at_k(rating_true=test_df2, 
                            rating_pred=all_predictions2, k=K)

        print(f"LR:{lr} ITEM_ALPHA:{ia} USER_ALPHA:{ua} PRECISION:{eval_precision2}")
        if(eval_precision2>best_precision):
            best_precision = eval_precision2
            LEARNING_RATE = lr
            ITEM_ALPHA = ia
            USER_ALPHA = ua
# Out:
# LR:0.375025 ITEM_ALPHA:1e-07 USER_ALPHA:1e-07 PRECISION:0.03432835820895522

# %% [markdown]
# ### Fit the LightFM model with additional user and item features

# %%
model2 = LightFM(loss='warp', no_components=NO_COMPONENTS, 
                 learning_rate=LEARNING_RATE, 
                 item_alpha=ITEM_ALPHA,
                 user_alpha=USER_ALPHA,
                 random_state=np.random.RandomState(SEEDNO))

# %%
model2.fit(interactions=train_interactions2,
           user_features=user_features,
           item_features=item_features,
           epochs=NO_EPOCHS);

# %% [markdown]
# ### Prepare model evaluation data

# %%
uids, iids, interaction_data = cross_validation._shuffle(
    interactions2.row, interactions2.col, interactions2.data, 
    random_state=np.random.RandomState(SEEDNO))

uid_map, ufeature_map, iid_map, ifeature_map = dataset2.mapping()
with open('uid_map.pickle', 'wb') as file:
    pickle.dump(uid_map, file, protocol=pickle.HIGHEST_PROTOCOL)
with open('iid_map.pickle', 'wb') as file:
    pickle.dump(iid_map, file, protocol=pickle.HIGHEST_PROTOCOL)
uid_map, iid_map
# Out:
# ({'5df49b32cc709107827fb3c7': 0,
#   '5ec3ba5374f7660d73aa1201': 1,
#   '5ec2204374f7660d73aa100f': 2,
#   '5d7c994d5720533e15c3b1e9': 3,
#   '5de50d768eab6401affbb135': 4,
#   '5deeef6142a8854bf6eabab9': 5,
#   '5d6d2bb87fa40e1417a49315': 6,
#   '5e3563348d344822fed4d13a': 7,
#   '5defd51362624b0135ea9fd2': 8,
#   '5e5af599d701ab08af792b63': 9,
#   '5ed3748576027d35905ccaab': 10,
#   '5ed0defa76027d35905cc2de': 11,
#   '5d610ae1653a331687083239': 12,
#   '5ed3cbcbbd514d602c1530a7': 13,
#   '5ed3737976027d35905ccaa2': 14,
#   '5ed0cfc676027d35905cc26a': 15,
#   '5d60098a653a331687083238': 16,
#   '5ed350ed76027d35905cca2c': 17,
#   '5ece02427023451e66223861': 18,
#   '5ed2edf176027d35905cc961': 19,
#   '5d618359fc5fcf3bdd9a0910': 20,
#   '5ed0bfc176027d35905cc1f8': 21,
#   '5ecb979eeaff6b0c3a58a4f0': 22,
#   '5ed0dfec76027d35905cc2ec': 23,
#   '5ed35aa376027d35905cca67': 24,
#   '5ed24d5a76027d35905cc7d7': 25,
#   '5ed13bb076027d35905cc4ba': 26,
#   '5ed3e898bd514d602c1530de': 27,
#   '5ed09e8576027d35905cc164': 28,
#   '5ed232b976027d35905cc689': 29,
#   '5ecdf7397023451e66223784': 30,
#   '5ed12ae476027d35905cc4a1': 31,
#   '5ed0fc0976027d35905cc448': 32,
#   '5ed0d9bc76027d35905cc2c2': 33,
#   '5e35a5ed8d344822fed4d13e': 34,
#   '5e3fd57aeab55d319938a826': 44,
#   '5e37d490eab55d319938a713': 45,
#   '5ec2e16074f7660d73aa1154': 46,
#   '5ec278b574f7660d73aa10d5': 47,
#   '5ed1ff0276027d35905cc60d': 48,
#   '5ed13d2876027d35905cc4c2': 49,
#   '5ecfb35c76027d35905cbfbc': 50,
#   '5ecf96e876027d35905cbf46': 51,
#   '5ed23cb876027d35905cc788': 52,
#   '5d7d405e5720533e15c3b1f3': 53,
#   '5ea7cd9610426255a7aa9bd2': 54,
#   '5ecd6ba47023451e66223604': 55,
#   '5eca6ddbec493f4a26558a46': 56,
#   '5eca7601ec493f4a26558a62': 57,
#   '5ecf23b87023451e66223944': 58,
#   '5ed0e20776027d35905cc2fe': 59,
#   '5ecfafcc76027d35905cbfb0': 60,
#   '5ea80a7e10426255a7aa9be2': 61,
#   '5ec7ad1aec493f4a26558869': 62,
#   '5ec7abfdec493f4a26558860': 63,
#   '5ec57914f2781131cc7e51c8': 64,
#   '5e2d4737c85ab714a7da66d9': 65,
#   '5ecb7567eaff6b0c3a58a4cf': 66,
#   '5e8c2d01a3258347b42f2627': 67,
#   '5e52e7abd701ab08af7929f8': 68,
#   '5e3674c68d344822fed4d152': 69,
#   '5e51a9e8d701ab08af7929dc': 70,
#   '5e52f911d701ab08af792a12': 71,
#   '5e8c993da3258347b42f264d': 72,
#   '5e8cc876a3258347b42f26a3': 73,
#   '5eb1df6d10426255a7aaa029': 74,
#   '5e8cb88ea3258347b42f267e': 75,
#   '5e8ccfb5a3258347b42f26bc': 76,
#   '5eb2ce0c10426255a7aaa078': 77,
#   '5eb0f27f10426255a7aa9fa2': 78,
#   '5eb1407c10426255a7aa9fdb': 79,
#   '5ea3227010426255a7aa9ac1': 80,
#   '5eabfaf510426255a7aa9da0': 81,
#   '5ea321dd10426255a7aa9abd': 82,
#   '5e77c625cfc8b713f5ac7c0b': 83,
#   '5eabf76a10426255a7aa9cfb': 84,
#   '5eac350110426255a7aa9e92': 85,
#   '5e5b561cd701ab08af792b8a': 86,
#   '5e5b59bcd701ab08af792b8f': 87,
#   '5eb2cbde10426255a7aaa074': 88,
#   '5ea30f6010426255a7aa9a9c': 89,
#   '5ea323a010426255a7aa9aca': 90,
#   '5ea319ee10426255a7aa9aa4': 91,
#   '5ea029e9a3258347b42f2e85': 92,
#   '5ea31faf10426255a7aa9ab5': 93,
#   '5ea3213010426255a7aa9abb': 94,
#   '5e943363a3258347b42f2813': 95,
#   '5e8d539ba3258347b42f26d8': 96,
#   '5e77bdc2cfc8b713f5ac7be4': 97,
#   '5e81c1e6a3258347b42f22dd': 98,
#   '5e7304761b24db0468e90ce7': 99,
#   '5e79b32ecfc8b713f5ac7d3f': 100,
#   '5e77738bcfc8b713f5ac7b36': 101,
#   '5e8448aba3258347b42f2447': 102,
#   '5e81bc41a3258347b42f220a': 103,
#   '5e81ba06a3258347b42f21ef': 104,
#   '5e81be54a3258347b42f221d': 105,
#   '5e7f4fb3a3258347b42f2156': 106,
#   '5e773c89cfc8b713f5ac7ac9': 107,
#   '5ed09ad076027d35905cc15f': 108,
#   '5e51a46ad701ab08af7929cf': 432,
#   '5e501d55d15de17a8cf1b91f': 433,
#   '5e4dab15f5561b1994c8e446': 434,
#   '5e4ed85af5561b1994c8e470': 435,
#   '5e4c2e65f5561b1994c8e3bd': 436,
#   '5e4c3c09f5561b1994c8e3e6': 437,
#   '5e4c3873f5561b1994c8e3d9': 438,
#   '5e5196b5d701ab08af7929a8': 439,
#   '5e50207cd15de17a8cf1b92c': 440,
#   '5e5023f1d15de17a8cf1b939': 441,
#   '5e5facf649d7f322c033e02b': 442,
#   '5e5e3b35fbc8805f69e02c9e': 443,
#   '5e733f1c1b24db0468e90cf1': 444,
#   '5e901b98a3258347b42f2708': 445,
#   '5e901e9da3258347b42f2711': 446,
#   '5ed0007a76027d35905cc0ea': 447,
#   '5df64ad1cc709107827fb3dd': 448,
#   '5d81323a6c53455f896e6044': 449,
#   '5e897f6ca3258347b42f25cd': 450,
#   '5e783590cfc8b713f5ac7c5d': 451,
#   '5dde6a91369b28584ecca156': 452,
#   '5eb45ca210426255a7aaa0b5': 453,
#   '5e04fb252a37d20505da2a2b': 454,
#   '5ea45fdf10426255a7aa9b34': 455,
#   '5ea04678a3258347b42f2e8a': 456,
#   '5e9651d5a3258347b42f2a9f': 457,
#   '5e9435f7a3258347b42f281a': 458,
#   '5e94bf78a3258347b42f2925': 459,
#   '5da745b6019399436815c4cd': 460,
#   '5ea31e5610426255a7aa9ab0': 461,
#   '5e9483b6a3258347b42f2860': 462,
#   '5e4d359cf5561b1994c8e424': 463,
#   '5e31a591c85ab714a7da6760': 464,
#   '5e27002d2a37d20505da2c13': 465,
#   '5e2f1811c85ab714a7da670d': 466,
#   '5e2867f6025ae20886de205a': 467,
#   '5dea816a42a8854bf6eaba89': 468,
#   '5e9f4215a3258347b42f2e4b': 469,
#   '5e966ad3a3258347b42f2aaf': 470,
#   '5e81a441a3258347b42f21d1': 471,
#   '5e65346c85ae350860168b53': 472,
#   '5d9b3514979d5962253c2f90': 473,
#   '5e776c1fcfc8b713f5ac7b23': 474,
#   '5e7743ebcfc8b713f5ac7aeb': 475,
#   '5e948155a3258347b42f2850': 476,
#   '5e5bdf4fd701ab08af792bfd': 477,
#   '5ea047d5a3258347b42f2e96': 478,
#   '5e94452ea3258347b42f282a': 479,
#   '5e778ffccfc8b713f5ac7b50': 480,
#   '5e767d501b24db0468e90d54': 481,
#   '5e908602a3258347b42f275b': 482,
#   '5e964006a3258347b42f2a65': 483,
#   '5e7220891b24db0468e90ce2': 484,
#   '5e964200a3258347b42f2a6d': 485,
#   '5e787636cfc8b713f5ac7cbe': 486,
#   '5d80ecfd6c53455f896e601a': 487,
#   '5e79b8becfc8b713f5ac7d45': 488,
#   '5e79cf2acfc8b713f5ac7d4e': 489,
#   '5e3ab644eab55d319938a72d': 490,
#   '5e78d6dccfc8b713f5ac7cf4': 491,
#   '5dd1751db802e41ed198b680': 492})

# %%
with Timer() as test_time:
    test_df2 = prepare_test_df(test_idx, uids, iids, uid_map, iid_map, weights2)
print(f"Took {test_time.interval:.1f} seconds for prepare and predict test data.")  
test_df2.head()
# Out:
# Took 0.0 seconds for prepare and predict test data.
#                      userID                    itemID  rating
# 0  5df20f1fee4bb5252b4f5351  5e4c435cf5561b1994c8e400     1.0
# 1  5d610ae1653a331687083239  5e8308c4a3258347b42f23ed     1.0
# 2  5d60098a653a331687083238  5eac349010426255a7aa9e29     1.0
# 3  5ea890e410426255a7aa9c16  5e895d87a3258347b42f25bb     1.0
# 4  5e1ef04c2a37d20505da2b8b  5eb6de2dfd92f539c465dd83     1.0

# %%
with Timer() as test_time:
    all_predictions2 = prepare_all_predictions(data, uid_map, iid_map, 
                                              interactions=train_interactions2,
                                               user_features=user_features,
                                               item_features=item_features,
                                               model=model2,
                                               num_threads=NO_THREADS)

print(f"Took {test_time.interval:.1f} seconds for prepare and predict all data.")
# Out:
# Took 10.1 seconds for prepare and predict all data.

# %% [markdown]
# ### Model evaluation and comparison

# %%
eval_precision2 = precision_at_k(rating_true=test_df2, 
                                rating_pred=all_predictions2, k=K)
eval_recall2 = recall_at_k(test_df2, all_predictions2, k=K)

print(
    "------ Using only explicit ratings ------",
    f"Precision@K:\t{eval_precision:.6f}",
    f"Recall@K:\t{eval_recall:.6f}",
    "\n------ Using both implicit and explicit ratings ------",
    f"Precision@K:\t{eval_precision2:.6f}",
    f"Recall@K:\t{eval_recall2:.6f}",
    sep='\n')
# Out:
# ------ Using only explicit ratings ------
# Precision@K:	0.034328
# Recall@K:	0.133274
#
# ------ Using both implicit and explicit ratings ------
# Precision@K:	0.037313
# Recall@K:	0.239093

# %% [markdown]
# ### Evaluation metrics comparison

# %%
print(
    "------ Using Repo's evaluation methods ------",
    f"Time [sec]:\t{(time_reco1+time_reco2+time_reco3):.1f}",
#     "\n------ Using LightFM evaluation methods ------",
#     f"Time [sec]:\t{time_lfm:.1f}",
    sep='\n')
# Out:
# ------ Using Repo's evaluation methods ------
# Time [sec]:	19.1

# %% [markdown]
# ## Evaluate model fitting process

# %%
output1, _ = track_model_metrics(model=model1, train_interactions=train_interactions, 
                              test_interactions=test_interactions, k=K,
                              no_epochs=NO_EPOCHS, no_threads=NO_THREADS)

# %%
output2, _ = track_model_metrics(model=model2, train_interactions=train_interactions2, 
                              test_interactions=test_interactions2, k=K,
                              no_epochs=NO_EPOCHS, no_threads=NO_THREADS, 
                              item_features=item_features,
                              user_features=user_features)

# %% [markdown]
# ### Performance comparison

# %%
for i in ['Precision', 'Recall']:
    sns.set_palette("Set2")
    plt.figure()
    sns.scatterplot(x="epoch", y="value", hue='data',
                data=compare_metric(df_list = [output1, output2], metric=i)
               ).set_title(f'{i} comparison using test set');

# %% [markdown]
# ## Similar users and items

# %% [markdown]
# ### User affinity

# %%
_, user_embeddings = model2.get_user_representations(features=user_features)
user_embeddings
# Out:
# array([[-0.14503694,  0.8039905 , -0.4029711 , ...,  0.87174827,
#          0.16886434, -0.5000943 ],
#        [ 0.11329399,  0.22754326, -0.13982655, ..., -0.03745572,
#          0.18275394,  0.539052  ],
#        [-0.00763982,  1.0751845 , -0.47231695, ...,  0.7129314 ,
#          0.1915096 , -0.324929  ],
#        ...,
#        [-0.15628797,  0.30277354,  0.0522608 , ..., -0.40000588,
#         -0.05106713,  0.3601698 ],
#        [-0.11804959,  0.5298451 , -0.24146825, ...,  0.6033182 ,
#          0.07923955, -0.35063392],
#        [-0.23662624, -0.13744253, -0.2785592 , ..., -0.47962987,
#         -0.2053147 ,  0.58984685]], dtype=float32)

# %%
similar_users(user_id=1, user_features=user_features, 
            model=model2)
# Out:
#    userID     score
# 0       8  0.999040
# 1       6  0.998996
# 2       7  0.998002
# 3       5  0.997761
# 4       3  0.997721
# 5      13  0.997496
# 6      62  0.997355
# 7      77  0.997325
# 8      16  0.997205
# 9     106  0.997202

# %% [markdown]
# ### Item affinity

# %%
_, item_embeddings = model2.get_item_representations(features=item_features)
item_embeddings
# Out:
# array([[ 0.5573949 ,  0.9864713 , -0.9100379 , ...,  0.18501464,
#          1.2651194 ,  0.00782661],
#        [ 0.50913566,  1.423477  , -0.72062254, ...,  0.23080629,
#          0.34751377,  0.16211897],
#        [-2.3705373 ,  0.87094736, -0.82532907, ...,  0.11863324,
#          0.9646424 ,  0.5176085 ],
#        ...,
#        [ 0.90935814,  0.4357223 , -0.18072581, ...,  0.47129416,
#          0.05984697, -0.3635678 ],
#        [-0.62071615,  0.25604257, -0.03255743, ..., -0.04901496,
#         -0.46484652, -0.3366678 ],
#        [-1.1525809 , -0.59018654, -0.4889273 , ..., -0.75842094,
#         -0.15463811,  0.3088231 ]], dtype=float32)

# %%
similar_items(item_id=10, item_features=item_features, 
            model=model2)
# Out:
#    itemID     score
# 0     358  0.986575
# 1       4  0.983740
# 2     109  0.982707
# 3      31  0.975392
# 4     356  0.968527
# 5      13  0.968337
# 6       9  0.965902
# 7      76  0.961415
# 8     435  0.960107
# 9      67  0.947977

# %% [markdown]
# ### Predict

# %%
# %%time

def sample_recommendation(
    user_id,
    data,
    uid_map,
    iid_map,
    interactions,
    model,
    num_threads,
    user_features=None,
    item_features=None,
):
    users, items, preds = [], [], []
    item = list(data.itemID.unique())
    for user in user_id:
        user = [user] * len(item)
        users.extend(user)
        items.extend(item)

    all_predictions = pd.DataFrame(data={"userID": users, "itemID": items})
    all_predictions["uid"] = all_predictions.userID.map(uid_map)
    all_predictions["iid"] = all_predictions.itemID.map(iid_map)

    dok_weights = interactions.todok()
    all_predictions["rating"] = all_predictions.apply(
        lambda x: dok_weights[x.uid, x.iid], axis=1
    )

    all_predictions = all_predictions[all_predictions.rating < 1].reset_index(drop=True)
    all_predictions = all_predictions.drop("rating", axis=1)

    all_predictions["prediction"] = all_predictions.apply(
        lambda x: model.predict(
            user_ids=x["uid"],
            item_ids=[x["iid"]],
            user_features=user_features,
            item_features=item_features,
            num_threads=num_threads,
        )[0],
        axis=1,
    )
    
    all_predictions['prediction'] = all_predictions.apply(lambda x: -x['prediction'],axis=1)
    all_predictions.sort_values(by=['prediction'],inplace=True)
    return all_predictions[["userID", "itemID", "prediction"]]

df = sample_recommendation( ['5ec3ba5374f7660d73aa1201'],data, uid_map, iid_map, 
# 16                                 Making of Daaku Art
# 17                       FASHION ILLUSTRATION (OP ART)
# 18                                          Aesthetic.
# 19                          Even and Odd Numbers (PHP)
# 20                          Launching an EC2 instance.
# 21                                    BEING CREATIVE☺☺
# 22                                      Near to nature
# 23                                      Be yourself !!
# 24                                         Hello world
# 25                                               Pride
# 26                                        Tree Drawing
# 27                                       GAN's Part(2)
# 28                                          Shivshakti
# 29                                        The Meenamma
# ..                                                 ...
# 432                    Why Do Millennials Change Jobs?
# 433                                             Abacus
# 434                                 Promotional video.
# 435                       E-Commerce - Business Models
# 436                          GOODS & SERVICE TAX (GST)
# 437                                   What is Ecology?
# 438                           HOW INTERNAL AUDIT WORKS
# 439                                       Types Of AI.
# 440                            Artificial Intelligence
# 441         5 Best Productivity Web Apps For Students.
# 442                                    3D composition.
# 443                  EDI (Electronic data interchange)
# 444      Employee Stock Option and Buyback Securities.
# 445                                    Personal growth
# 446           IMPORTANCE OF INTERNAL FINANCIAL CONTROL
# 447                                    Skeletal System
# 448                               Students Networking!
# 449  Preparation and Presentation of Company Final ...
# 450  Terrible Leadership And Its Influence In Compa...
# 451                      Let's discuss some Case laws!
# 452                                              Blues
# 453  Advantages of Online Shopping Over Offline Sho...
# 454  Interesting Facts On India That You Had No Ide...
# 455                     Nature of Industrial Disputes.
# 456                                    आमची मुंबाई !!!
# 457  How Chartered Accountants See Entrepreneurship...
# 458       Importance of Digital Marketing for Startups
# 459             The Best Tools For Financial Analysis.
# 460  Advantages of Online Shopping Over Offline Sho...
# 461                                       Biodiversity
#
#                                               category post_type
# 0             Fashion Design|Illustration|Watercolours   artwork
# 1    Fashion Design|Illustration|Conceptual|Waterco...   artwork
# 2                                             Drawings   artwork
# 3                                             Drawings   artwork
# 4                                             Learning     skill
# 5                                           Sculptures   artwork
# 6    Fashion Desigining|Pattern & Culture|Fashion T...      blog
# 7                                                  NaN   project
# 8                                             Learning     skill
# 9                 Computer Technology|Machine Learning      blog
# 10                                                 Art     skill
# 11                                         Photography   artwork
# 12                                            Drawings   artwork
# 13                                                 NaN   project
# 14                                         Pen and ink   artwork
# 15                                                 NaN   project
# 16                                                 Art     skill
# 17   Drawings|Fashion Design|Mixed Media|Conceptual...   artwork
# 18                                         Photography   artwork
# 19                                                 NaN   project
# 20                                          Technology     skill
# 21                                            Drawings   artwork
# 22                                            Painting   artwork
# 23                                         Photography   artwork
# 24                                  Fine Arts|Painting      blog
# 25                                   Drawings|Painting   artwork
# 26                                            Drawings   artwork
# 27                Computer Technology|Machine Learning      blog
# 28                                            Drawings   artwork
# 29   Drawings|Painting|Visual Arts|Artistic design|...   artwork
# ..                                                 ...       ...
# 432         Business|Corporate Social Responsibilities      blog
# 433                         Mathematics|Linear Algebra      blog
# 434                                      Video editing     skill
# 435  E Commerce|Shopping Platform|Other Online Plat...      blog
# 436                                       Taxation|GST      blog
# 437                                    Zoology|Ecology      blog
# 438                            Auditing|Internal Audit      blog
# 439        Computer Technology|Artificial Intelligence      blog
# 440        Computer Technology|Artificial Intelligence      blog
# 441  Human Resources|Performance In Organization|Or...      blog
# 442                                           Tapestry   artwork
# 443                  E Commerce|Other Online Platforms      blog
# 444     Marketing|Promotion And Distribution Decisions      blog
# 445                 Mass Media|International Relations      blog
# 446                Auditing|Internal Financial Control      blog
# 447                               Physiology|Osteology      blog
# 448                                                NaN      blog
# 449               Accounting|Fundamental Of Accounting      blog
# 450                         Management|Team Mangememnt      blog
# 451                                   Competition Laws      blog
# 452                                        Photography   artwork
# 453                              Marketing|Advertising      blog
# 454                             History|Indian History      blog
# 455  Legal Studies|Alternate Dispute Resolution|Int...      blog
# 456                             History|Indian History      blog
# 457                    Accounting|Financial Accounting      blog
# 458                              Marketing|Advertising      blog
# 459                         Finance|Financial Analysis      blog
# 460                              Marketing|Advertising      blog
# 461                                         Eco System      blog
#
# [462 rows x 6 columns]

# %% [markdown]
# ### Save and Load

# %%
import pickle

with open('model2.pickle', 'wb') as fle:
    pickle.dump(model2, fle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
model2

# %%
model2_copy = open("model2.pickle","rb")
model2_copy = pickle.load(model2_copy)
model2_copy

# %%
df = sample_recommendation( ['5ec3ba5374f7660d73aa1201'],data, uid_map, iid_map, 
                       interactions=train_interactions2,
                       user_features=user_features,
                       item_features=item_features,
                       model=model2_copy,
                       num_threads=NO_THREADS)
df.head()
# Out:
#                       userID                    itemID  prediction
# 79  5ec3ba5374f7660d73aa1201  5ec7aafbec493f4a26558857  112.490555
# 31  5ec3ba5374f7660d73aa1201  5ec7ad1aec493f4a26558869  112.499001
# 5   5ec3ba5374f7660d73aa1201  5eb2c11210426255a7aaa052  112.501228
# 48  5ec3ba5374f7660d73aa1201  5eb1407c10426255a7aa9fdb  112.551956
# 26  5ec3ba5374f7660d73aa1201  5eca7601ec493f4a26558a62  112.649551

# %% [markdown]
# ### Flask

# %%
import requests
import json

url = 'http://127.0.0.1:5000/'
params ={'user_id': '5ec3ba5374f7660d73aa1201'}
response = requests.get(url, params)
# response.json()
response, response.text
# Out:
# (<Response [200]>,
#  '<h1>RECOMMENDER ENGINE</h1><p>This is a prototype API for recommending products for an user.</p>')

# %%
data = ["5ec3ba5374f7660d73aa1201"]
j_data = json.dumps(data)

headers = {'content-type': 'application/json', 'Accept-Charset': 'UTF-8'}
url = 'http://127.0.0.1:5000/predict'

r = requests.post(url, data=j_data, headers=headers)
j_data, r
# Out:
# ('["5ec3ba5374f7660d73aa1201"]', <Response [200]>)

# %%
r.text
# Out:
# '[{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5ec7aafbec493f4a26558857","prediction":112.4905548096},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5ec7ad1aec493f4a26558869","prediction":112.4990005493},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5eb2c11210426255a7aaa052","prediction":112.5012283325},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5eb1407c10426255a7aa9fdb","prediction":112.5519561768},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5eca7601ec493f4a26558a62","prediction":112.6495513916},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5e9f4421a3258347b42f2e54","prediction":112.7699890137},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5ec2b27974f7660d73aa1115","prediction":112.8732757568},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5e8cc876a3258347b42f26a3","prediction":112.9337692261},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5eca6ddbec493f4a26558a46","prediction":112.9352493286},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5ecd5d417023451e662235c5","prediction":112.9625396729},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5ec57914f2781131cc7e51c8","prediction":112.9851913452},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5eba2dd3514aab59896bcc57","prediction":112.9913864136},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5ec601a0f2781131cc7e522e","prediction":113.0448684692},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5e8cb88ea3258347b42f267e","prediction":113.04662323},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5ec3c09274f7660d73aa1229","prediction":113.0537948608},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5eb1df6d10426255a7aaa029","prediction":113.0735778809},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5ec2f7c074f7660d73aa116e","prediction":113.083694458},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5ec7abfdec493f4a26558860","prediction":113.1230010986},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5ea3227010426255a7aa9ac1","prediction":113.1916275024},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5e8c2d01a3258347b42f2627","prediction":113.2462081909},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5ed13d2876027d35905cc4c2","prediction":113.2742767334},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5e8d539ba3258347b42f26d8","prediction":113.2974014282},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5e9a8271a3258347b42f2c35","prediction":113.3368225098},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5ecd6ba47023451e66223604","prediction":113.3812179565},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5eac350110426255a7aa9e92","prediction":113.4116439819},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5e9f3fd9a3258347b42f2e3f","prediction":113.4171218872},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5ea319ee10426255a7aa9aa4","prediction":113.4320297241},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5ecf96e876027d35905cbf46","prediction":113.4353256226},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5e99b1c6a3258347b42f2bf2","prediction":113.4704360962},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5e7f39a3a3258347b42f2151","prediction":113.4844970703},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5e99b786a3258347b42f2bfd","prediction":113.4926147461},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5eba2e94514aab59896bcc5a","prediction":113.5025405884},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5ecfafcc76027d35905cbfb0","prediction":113.5079040527},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5eb4fab110426255a7aaa0ed","prediction":113.5417480469},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5ea323a010426255a7aa9aca","prediction":113.5419082642},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5e8c993da3258347b42f264d","prediction":113.5522994995},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5ea3236810426255a7aa9ac8","prediction":113.5801086426},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5e7f4fb3a3258347b42f2156","prediction":113.5854034424},{"userID":"5ec3ba5374f7660d73aa1201","itemID":"5e7e66e7a3258347b42f213c","prediction":113.5963516235},{"userID":"5ec3ba5374f7 ...

# %%
import pandas as pd

table = pd.read_json(r.text)
table = table.merge(pd.read_csv("../Post dataset/posts.csv"), on='itemID')
table = table.merge(pd.read_csv("../Post dataset/users.csv"), on='userID')
table.head()
# Out:
#                      itemID  prediction                    userID  \
# 0  5ec7aafbec493f4a26558857  112.490555  5ec3ba5374f7660d73aa1201
# 1  5ec7ad1aec493f4a26558869  112.499001  5ec3ba5374f7660d73aa1201
# 2  5eb2c11210426255a7aaa052  112.501228  5ec3ba5374f7660d73aa1201
# 3  5eb1407c10426255a7aa9fdb  112.551956  5ec3ba5374f7660d73aa1201
# 4  5eca7601ec493f4a26558a62  112.649551  5ec3ba5374f7660d73aa1201
#
#                                    title  \
# 0                   FASHION ILLUSTRATION
# 1  FASHION ILLUSTRATION (street fashion)
# 2                         Gangster Style
# 3                       PENCIL RENDERING
# 4                     Always do Right 👍🏻
#
#                                             category post_type  \
# 0           Fashion Design|Illustration|Watercolours   artwork
# 1  Fashion Design|Illustration|Conceptual|Waterco...   artwork
# 2                                           Drawings   artwork
# 3                                           Drawings   artwork
# 4                                           Learning     skill
#
#               name gender      academics
# 0  Kushagra Sharma   male  undergraduate
# 1  Kushagra Sharma   male  undergraduate
# 2  Kushagra Sharma   male  undergraduate
# 3  Kushagra Sharma   male  undergraduate
# 4  Kushagra Sharma   male  undergraduate

# %%
import pickle

user_features = open("user_features.pickle","rb")
user_features = pickle.load(user_features)
print(type(user_features))
user_features

# %%
df = pd.DataFrame(user_features.toarray())
df
